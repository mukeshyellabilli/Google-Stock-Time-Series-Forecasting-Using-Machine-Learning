# 2010-01-05  15.695195  15.711712  15.554054  15.615365  15.615365  120067812
# 2010-01-06  15.662162  15.662162  15.174174  15.221722  15.221722  158988852
# 2010-01-07  15.250250  15.265265  14.831081  14.867367  14.867367  256315428
# 2010-01-08  14.814815  15.096346  14.742492  15.065566  15.065566  188783028
# ...               ...        ...        ...        ...        ...        ...
# 2022-12-23  87.110001  89.550003  87.070000  89.230003  89.230003   23003000
# 2022-12-27  88.800003  88.940002  87.010002  87.389999  87.389999   20097300
# 2022-12-28  86.980003  88.040001  85.940002  86.019997  86.019997   19523200
# 2022-12-29  86.620003  88.849998  86.610001  88.449997  88.449997   23333500
# 2022-12-30  86.980003  88.300003  86.570000  88.230003  88.230003   23986300
#
# [3272 rows x 6 columns]

# %%
df.describe()
# Out:
#               Open         High          Low        Close    Adj Close        Volume
# count  3272.000000  3272.000000  3272.000000  3272.000000  3272.000000  3.272000e+03
# mean     49.161187    49.650301    48.653316    49.160898    49.160898  6.017541e+07
# std      35.810449    36.216443    35.387644    35.804094    35.804094  4.957609e+07
# min      10.968719    11.068068    10.851602    10.912663    10.912663  9.312000e+06
# 25%      20.281718    20.426113    20.172359    20.295858    20.295858  2.894200e+07
# 50%      38.527750    38.931249    38.224501    38.563002    38.563002  4.123200e+07
# 75%      61.837625    62.265000    61.218125    61.738001    61.738001  7.927251e+07
# max     151.250000   151.546494   148.899002   149.838501   149.838501  5.923990e+08

# %% [markdown]
# ## **Visualization**

# %%
df.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
df["adj_close"].plot()
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ## **Augmunted Dicky-Fuller Test**
#
# The ADF test works by testing the null hypothesis that a unit root is present in the time series. Here’s a breakdown:
#
# * Null Hypothesis (H0): The time series has a unit root (it is non-stationary).
# * Alternative Hypothesis (H1): The time series does not have a unit root (it is stationary).

# %%
### Testing For Stationarity

from statsmodels.tsa.stattools import adfuller

# %%
test_result=adfuller(df['adj_close'])

# %%
result=adfuller(df['adj_close'])
result  #returns a tuple containing various test statistics and critical values required for the test.
# Out:
# (-0.630788131705103,
#  0.8638723239459678,
#  22,
#  3249,
#  {'1%': -3.4323643041051666,
#   '5%': -2.862429999065346,
#   '10%': -2.5672437656428793},
#  9964.939753649425)

# %%
#Ho: It is non stationary
#H1: It is stationary

def adfuller_test(adj_close):
    result=adfuller(adj_close)
    labels = ['ADF Test Statistic','p-value','#Lags Used','Number of Observations Used']
    for value,label in zip(result,labels):
        print(label+' : '+str(value) )
    if result[1] <= 0.05:
        print("strong evidence against the null hypothesis(Ho), reject the null hypothesis. Data has no unit root and is stationary")
    else:
        print("weak evidence against null hypothesis, time series has a unit root, indicating it is non-stationary ")

# %%
adfuller_test(df['adj_close'])
# Out:
# ADF Test Statistic : -0.630788131705103
# p-value : 0.8638723239459678
# #Lags Used : 22
# Number of Observations Used : 3249
# weak evidence against null hypothesis, time series has a unit root, indicating it is non-stationary

# %% [markdown]
# ## **Differencing**

# %%
df['adj_close First Difference'] = df['adj_close'] - df['adj_close'].shift(1)

# %%
df.head()
# Out:
#                  open       high        low      close  adj_close     volume  adj_close First Difference
# Date
# 2010-01-04  15.689439  15.753504  15.621622  15.684434  15.684434   78169752                         NaN
# 2010-01-05  15.695195  15.711712  15.554054  15.615365  15.615365  120067812                   -0.069069
# 2010-01-06  15.662162  15.662162  15.174174  15.221722  15.221722  158988852                   -0.393643
# 2010-01-07  15.250250  15.265265  14.831081  14.867367  14.867367  256315428                   -0.354355
# 2010-01-08  14.814815  15.096346  14.742492  15.065566  15.065566  188783028                    0.198199

# %%
df['adj_close'].shift(1)
# Out:
# Date
# 2010-01-04          NaN
# 2010-01-05    15.684434
# 2010-01-06    15.615365
# 2010-01-07    15.221722
# 2010-01-08    14.867367
#                 ...
# 2022-12-23    87.760002
# 2022-12-27    89.230003
# 2022-12-28    87.389999
# 2022-12-29    86.019997
# 2022-12-30    88.449997
# Name: adj_close, Length: 3272, dtype: float64

# %%
df['adj_close First Difference'].plot()
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ## **Auto Regressive Model**

# %%
from pandas.plotting import autocorrelation_plot
autocorrelation_plot(df['adj_close'])
plt.show()

# %% [markdown]
# * **High Initial Value**: The plot starts at 1 because any series is perfectly correlated with itself at lag 0.
# * **Sharp Decline**: The autocorrelation drops quickly, meaning the stock prices are strongly related to their recent past values but this relationship weakens fast.
# * **Fluctuations Around Zero**: After the initial drop, the values fluctuate around zero, indicating that the stock prices don’t have a strong long-term pattern based on past values.
# * **Confidence Intervals**: The dashed lines show the range where values are considered random. Most values fall within these lines, suggesting that beyond short-term lags, the patterns are likely random.

# %%
from statsmodels.graphics.tsaplots import plot_acf,plot_pacf
import statsmodels.api as sm

# %%
fig = plt.figure(figsize=(12,8))
ax1 = fig.add_subplot(211)
fig = sm.graphics.tsa.plot_acf(df['adj_close First Difference'].iloc[1:],lags=40,ax=ax1)
ax2 = fig.add_subplot(212)
fig = sm.graphics.tsa.plot_pacf(df['adj_close First Difference'].iloc[1:],lags=40,ax=ax2)

# %%
# For non-seasonal data
#p=1, d=1, q=0 or 1
from statsmodels.tsa.arima.model import ARIMA

# %%
model=ARIMA(df['adj_close'],order=(1,1,1))
model_fit=model.fit()

# %%
model_fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ...
# Dep. Variable:              adj_close   No. Observations:                 3272
# Model:                 ARIMA(1, 1, 1)   Log Likelihood               -5028.562
# Date:                Mon, 23 Sep 2024   AIC                          10063.125
# Time:                        15:30:34   BIC                          10081.403
# Sample:                             0   HQIC                         10069.671
#                                - 3272
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.7140      0.055     13.054      0.000       0.607       0.821
# ma.L1         -0.7649      0.051    -15.063      0.000      -0.864      -0.665
# sigma2         1.2671      0.012    108.700      0.000       1.244       1.290
# ...

# %%
df['forecast']=model_fit.predict(start=90,end=103,dynamic=True)
df[['adj_close','forecast']].plot(figsize=(12,8))
# Out:
# <Axes: xlabel='Date'>

# %%
from pandas.tseries.offsets import DateOffset
future_dates=[df.index[-1]+ DateOffset(months=x)for x in range(0,24)]

# %%
future_datest_df=pd.DataFrame(index=future_dates[1:],columns=df.columns)

# %%
future_datest_df.tail()
# Out:
#            open high  low close adj_close volume adj_close First Difference forecast
# 2024-07-30  NaN  NaN  NaN   NaN       NaN    NaN                        NaN      NaN
# 2024-08-30  NaN  NaN  NaN   NaN       NaN    NaN                        NaN      NaN
# 2024-09-30  NaN  NaN  NaN   NaN       NaN    NaN                        NaN      NaN
# 2024-10-30  NaN  NaN  NaN   NaN       NaN    NaN                        NaN      NaN
# 2024-11-30  NaN  NaN  NaN   NaN       NaN    NaN                        NaN      NaN

# %%
future_df=pd.concat([df,future_datest_df])

# %%
future_df['forecast'] = model_fit.predict(start = 104, end = 120, dynamic= True)
future_df[['adj_close', 'forecast']].plot(figsize=(12, 8))
# Out:
# <Axes: >
